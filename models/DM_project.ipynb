# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.7 MB/s eta 0:00:00

# %% [markdown]
# ## **model1**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fylEl4srxlLC6dCwjHgQ")
project = rf.workspace("hudaqq").project("my-first-project-edolo")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 101.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 127.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-4 in yolov8:: 100%|██████████| 1593/1593 [00:00<00:00, 9169.75it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/My-First-Project-4/data.yaml",
    epochs=120,
    imgsz=640,
    batch=16,
    lr0=0.003,
    patience=20,
    project="BITMATCH",
    name="/content/drive/MyDrive/screw_v1",
    save=True
)
# Out:
# Ultralytics 8.3.244 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### TEST SONUCU

# %%
from ultralytics import YOLO

# Modeli yükle
model = YOLO("/content/bitmatch-screw-detection/models/1/weights/best.pt")

# Test seti üzerinde değerlendir
metrics = model.val(
    data="/content/My-First-Project-4/data.yaml",
    split="test",
    name="/content/bitmatch-screw-detection/models/1/runs",
)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 763.1±319.2 MB/s, size: 31.6 KB)
# val: Scanning /content/My-First-Project-4/test/labels.cache... 33 images, 4 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 33/33 49.4Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.0it/s 1.0s
#                    all         33         62      0.532      0.578      0.521      0.314
#       Hex Socket Allen          5          9      0.608      0.521      0.637       0.46
#               Phillips          6          9      0.294      0.667      0.404      0.192
#               Pozidriv          9         17      0.571      0.647      0.562       0.31
#                Slotted          7         18      0.729      0.389      0.576      0.357
# ...

# %% [markdown]
# ## **model2 imgsz = 960**

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/My-First-Project-4/data.yaml",
    epochs=120,
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=20,
    project="BITMATCH",
    name="/content/drive/MyDrive/screw_v2",
    save=True
)
# Out:
# Ultralytics 8.3.244 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### TEST SONUCU

# %%
from ultralytics import YOLO

# Modeli yükle
model = YOLO("/content/bitmatch-screw-detection/models/2/weights/best.pt")

# Test seti üzerinde değerlendir
metrics = model.val(
    data="/content/My-First-Project-4/data.yaml",
    split="test",
    name="/content/bitmatch-screw-detection/models/2/runs",
)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 807.9±192.3 MB/s, size: 31.6 KB)
# val: Scanning /content/My-First-Project-4/test/labels... 33 images, 4 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 33/33 1.5Kit/s 0.0s
# val: New cache created: /content/My-First-Project-4/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3it/s 1.3s
#                    all         33         62      0.621      0.528      0.589       0.35
#       Hex Socket Allen          5          9      0.857      0.666      0.897      0.617
#               Phillips          6          9      0.288      0.667      0.441      0.213
#               Pozidriv          9         17      0.536      0.353      0.532      0.284
# ...

# %% [markdown]
# ## **model3 datset preproceded**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fylEl4srxlLC6dCwjHgQ")
project = rf.workspace("hudaqq").project("my-first-project-edolo")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-7 in yolov8:: 100%|██████████| 1641/1641 [00:00<00:00, 7898.17it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/My-First-Project-7/data.yaml",
    epochs=100,
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=30,
    project="BITMATCH",
    name="/content/drive/MyDrive/screw_v3",
    save=True
)

# %% [markdown]
# ### TEST SONUCU

# %%
from ultralytics import YOLO

# Modeli yükle
model = YOLO("/content/bitmatch-screw-detection/models/3/weights/best.pt")

# Test seti üzerinde değerlendir
metrics = model.val(
    data="/content/My-First-Project-7/data.yaml",
    split="test",
    name="/content/bitmatch-screw-detection/models/3/runs",
)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1016.3±299.4 MB/s, size: 46.8 KB)
# val: Scanning /content/My-First-Project-7/test/labels.cache... 33 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 33/33 69.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         33         70      0.694      0.612      0.642      0.439
#       Hex Socket Allen          6         13      0.844      0.834      0.872      0.634
#               Phillips          7         10       0.43        0.7      0.532      0.287
#               Pozidriv          9         17      0.621      0.578      0.541      0.308
#                Slotted          9         21      0.805      0.394       0.56      0.397
# ...

# %% [markdown]
# ## **GIT**

# %%
# %cd bitmatch-screw-detection
# Out:
# /content/bitmatch-screw-detection

# %%
# !cp -r /content/drive/MyDrive/screw_v13 /content/bitmatch-screw-detection/models/1

# %%
# !git status
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean

# %%
# Out:
# [main 9c47042] test sonuclari eklendi 1-5 modelleri icin
#  1684 files changed, 1638 insertions(+)
#  create mode 100644 My-First-Project-13/README.roboflow.txt
#  create mode 100644 My-First-Project-13/data.yaml
#  create mode 100644 My-First-Project-13/test/images/20240401130700_jpg.rf.d135551ca7f401dd383296c82abc784d.jpg
#  create mode 100644 My-First-Project-13/test/images/20251203_100107_jpg.rf.c672a279013bbce4c112963146d1f5f1.jpg
#  create mode 100644 My-First-Project-13/test/images/20251225_221828_jpg.rf.450d940c50ac5e8169a848336989c61f.jpg
#  create mode 100644 My-First-Project-13/test/images/20251226_093601_jpg.rf.621b4bbe5a935cfe26ecff829c7f1a8c.jpg
#  create mode 100644 My-First-Project-13/test/images/20251227_090455_jpg.rf.ea3e19bd75ca9bbcedfae120c93bcf92.jpg
#  create mode 100644 My-First-Project-13/test/images/20251227_141432_jpg.rf.028c9d8c6cf776b8da71935c9180918d.jpg
# ...

# %% [markdown]
# ## **model4+5 yolov8s**

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/My-First-Project-7/data.yaml",
    epochs=100,
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=30,
    project="BITMATCH",
    name="/content/bitmatch-screw-detection/models/4",
    save=True
)
# Out:
# ...
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/My-First-Project-7/data.yaml",
    epochs=150, # epoch sayisi degisti bir tek
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=30,
    project="BITMATCH",
    name="/content/bitmatch-screw-detection/models/5",
    save=True
)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### TEST SONUCU

# %%
from ultralytics import YOLO

# Modeli yükle
model = YOLO("/content/bitmatch-screw-detection/models/4/weights/best.pt")

# Test seti üzerinde değerlendir
metrics = model.val(
    data="/content/My-First-Project-7/data.yaml",
    split="test",
    name="/content/bitmatch-screw-detection/models/4/runs",
)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1069.3±256.8 MB/s, size: 45.2 KB)
# val: Scanning /content/My-First-Project-7/test/labels.cache... 33 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 33/33 70.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3it/s 1.3s
#                    all         33         70       0.69      0.642      0.697      0.437
#       Hex Socket Allen          6         13      0.917      0.852      0.973      0.653
#               Phillips          7         10       0.37        0.7      0.653      0.305
#               Pozidriv          9         17      0.709      0.647      0.616      0.347
#                Slotted          9         21      0.923      0.569      0.692      0.441
# ...

# %% [markdown]
# ## **model6 val number/class**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fylEl4srxlLC6dCwjHgQ")
project = rf.workspace("hudaqq").project("my-first-project-edolo")
version = project.version(13)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-13 in yolov8:: 100%|██████████| 1629/1629 [00:00<00:00, 7339.11it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/bitmatch-screw-detection/My-First-Project-13/data.yaml",
    epochs=120,
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=30,
    project="BITMATCH",
    name="/content/bitmatch-screw-detection/models/6",
    save=True
)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

# Modeli yükle
model = YOLO("/content/bitmatch-screw-detection/models/6/weights/best.pt")

# Test seti üzerinde değerlendir
metrics = model.val(
    data="/content/bitmatch-screw-detection/My-First-Project-13/data.yaml",
    split="test",
    name="/content/bitmatch-screw-detection/models/6/runs",
)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 877.1±297.3 MB/s, size: 22.8 KB)
# val: Scanning /content/bitmatch-screw-detection/My-First-Project-13/test/labels.cache... 33 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 33/33 66.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.4it/s 1.3s
#                    all         33         67      0.588      0.701      0.656      0.402
#       Hex Socket Allen          7         11      0.618      0.737      0.748      0.494
#               Phillips          6         11      0.446      0.727      0.631       0.32
#               Pozidriv          5          9      0.367      0.667      0.437      0.252
# ...

# %% [markdown]
# ### TFLite export

# %%
from ultralytics import YOLO

# best.pt dosyanın yolu (gerekirse yolu düzelt)
model = YOLO("/content/bitmatch-screw-detection/models/62/weights/best.pt")

# TFLite export
model.export(
    format="tflite",   # çıktı formatı
    int8=True          # mobil için önerilen quantization
)

print("✅ TFLite export tamamlandı")
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 72 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/bitmatch-screw-detection/models/62/weights/best.pt' with input shape (1, 3, 960, 960) BCHW and output shape(s) (1, 9, 18900) (21.5 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<2.0.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 20 packages in 2.40s
# Prepared 11 packages in 3.88s
# Installed 11 packages in 261ms
#  + ai-edge-litert==2.1.0
# ...

# %%
# !rm -rf /content/bitmatch-screw-detection/models/62
