# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fylEl4srxlLC6dCwjHgQ")
project = rf.workspace("hudaqq").project("my-first-project-edolo")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 101.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 127.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-4 in yolov8:: 100%|██████████| 1593/1593 [00:00<00:00, 9169.75it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# !ls My-First-Project-3/
# !cat My-First-Project-3/data.yaml
# Out:
# drive  My-First-Project-3  sample_data
# data.yaml  README.roboflow.txt	test  train  valid
# names:
# - Hex Socket Allen
# - Phillips
# - Pozidriv
# - Slotted
# - Torx
# nc: 5
# roboflow:
#   license: Private
#   project: my-first-project-edolo
#   url: https://app.roboflow.com/hudaqq/my-first-project-edolo/3
#   version: 3
#   workspace: hudaqq
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.7 MB/s eta 0:00:00

# %%
# !rm -rf /content/My-First-Project-3

# %% [markdown]
# ## **model1 (v1)**

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/My-First-Project-4/data.yaml",
    epochs=120,
    imgsz=640,
    batch=16,
    lr0=0.003,
    patience=20,
    project="BITMATCH",
    name="/content/drive/MyDrive/screw_v1",
    save=True
)
# Out:
# Ultralytics 8.3.244 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ## **model2 (v2) imgsz = 960**

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/My-First-Project-4/data.yaml",
    epochs=120,
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=20,
    project="BITMATCH",
    name="/content/drive/MyDrive/screw_v2",
    save=True
)
# Out:
# Ultralytics 8.3.244 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ## **model3 (v3) datset preprocedded**

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/My-First-Project-7/data.yaml",
    epochs=100,
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=30,
    project="BITMATCH",
    name="/content/drive/MyDrive/screw_v3",
    save=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fylEl4srxlLC6dCwjHgQ")
project = rf.workspace("hudaqq").project("my-first-project-edolo")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-7 in yolov8:: 100%|██████████| 1641/1641 [00:00<00:00, 7898.17it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/My-First-Project-7/data.yaml",
    epochs=100,
    imgsz=960,
    batch=16,
    lr0=0.003,
    patience=30,
    project="BITMATCH",
    name="/content/drive/MyDrive/screw_v3",
    save=True
)

# %%
# notebook
# !cp /content/drive/MyDrive/screw_v3/train.ipynb .

# data config
# !cp /content/My-First-Project-7/data.yaml .

# rapor klasörü varsa
# !cp -r /content/drive/MyDrive/report .

# %%
# %cd bitmatch-screw-detection
# !ls
# Out:
# /content/bitmatch-screw-detection

# %%
# notebook
# !cp /content/drive/MyDrive/screw_v3/train.ipynb .

# data config
# !cp /content/My-First-Project-7/data.yaml .

# rapor klasörü varsa
# !cp -r /content/drive/MyDrive/report .

# %%
# !cp -r /content/drive/MyDrive/Colab Notebooks/DM_project.ipynb /content/bitmatch-screw-detection/models/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/DM_project.ipynb': No such file or directory

# %%
# !git status
# !git add .
# !git commit -m "dataset v4"
# !git push
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "030722088@std.izu.edu.tr"
# !git config --global user.name "Hudakasim"

# %%
# Out:
# Enumerating objects: 2540, done.
# Counting objects: 100% (2540/2540), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (1876/1876), done.
# Writing objects: 100% (2540/2540), 62.08 MiB | 20.47 MiB/s, done.
# Total 2540 (delta 12), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (12/12), done.
# To https://github.com/Hudakasim/bitmatch-screw-detection.git
#  * [new branch]      main -> main
